# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import pandas as pd
from sklearn.cluster import KMeans
df=pd.read_csv('cleandata/merged_auduobook.csv')
df.head()

print(df.shape)
print(df.columns)

vectorizer = TfidfVectorizer(stop_words='english')
x=vectorizer.fit_transform(df['Book_Name_x'])
# Out:
# (4352, 14)
# Index(['Book_Name_x', 'Author_x', 'Rating_x', 'Number of Reviews_x', 'Price_x',
#        'Description', 'Listening Time', 'Ranks and Genre', 'Matched_Book_Name',
#        'Book_Name_y', 'Author_y', 'Rating_y', 'Number of Reviews_y',
#        'Price_y'],
#       dtype='object')

# %%
bookname =  linear_kernel(x, x)
print(bookname.shape)
# Out:
# (4352, 4352)

# %%
# KMeans Clustering
kmeans = KMeans(n_clusters=5, random_state=42)
cluster_labels = kmeans.fit_predict(x)
df['cluster'] = cluster_labels

# %%
print("Cluster Labels:", cluster_labels)
print("DataFrame with Clusters:\n", df)
# Out:
# Cluster Labels: [2 2 2 ... 2 2 2]
# DataFrame with Clusters:
#                                              Book_Name_x  \
# 0     Think Like a Monk: The Secret of How to Harnes...
# 1     Ikigai: The Japanese Secret to a Long and Happ...
# 2     The Subtle Art of Not Giving a F*ck: A Counter...
# 3     Atomic Habits: An Easy and Proven Way to Build...
# 4     Life's Amazing Secrets: How to Find Balance an...
# ...                                                 ...
# 4347                                  The Little Prince
# 4348      Things I Wish I'd Known Before We Got Married
# 4349      Things I Wish I'd Known Before We Got Married
# 4350  The Disease Delusion: Conquering the Causes of...
# 4351  The Disease Delusion: Conquering the Causes of...
#
#                       Author_x  Rating_x  Number of Reviews_x  Price_x  \
# 0                   Jay Shetty       4.9                371.0    10080
# 1                Héctor García       4.6               3682.0      615
# 2                  Mark Manson       4.4              20306.0    10378
# 3                  James Clear       4.6               4678.0      888
# 4               Gaur Gopal Das       4.6               4308.0     1005
# ...                        ...       ...                  ...      ...
# 4347  Antoine de Saint-Exupéry       3.3                 58.0      234
# 4348              Gary Chapman       4.7               1388.0      516
# 4349              Gary Chapman       4.7               1388.0      516
# 4350      Dr. Jeffrey S. Bland       4.7                259.0    12356
# 4351      Dr. Jeffrey S. Bland       4.7                259.0    12356
#
#                                             Description  \
# 0     Over the past three years, Jay Shetty has beco...
# 1                            Brought to you by Penguin.
# 2     In this generation-defining self-help guide, a...
# 3                            Brought to you by Penguin.
# 4     Stop going through life,  Start growing throug...
# ...                                                 ...
# 4347  \n\nOops!\nIt's rush hour and traffic is pilin...
# 4348  \n\nOops!\nIt's rush hour and traffic is pilin...
# 4349  \n\nOops!\nIt's rush hour and traffic is pilin...
# 4350  Disease care vs health care: Which would you c...
# 4351  Disease care vs health care: Which would you c...
#
#                Listening Time  \
# 0     10 hours and 54 minutes
# 1      3 hours and 23 minutes
# 2      5 hours and 17 minutes
# 3      5 hours and 35 minutes
# 4      6 hours and 25 minutes
# ...                       ...
# 4347                       -1
# 4348                       -1
# 4349                       -1
# 4350                       -1
# 4351                       -1
#
#                                         Ranks and Genre  \
# 0     ,#1 in Audible Audiobooks & Originals (See Top...
# 1     ,#2 in Audible Audiobooks & Originals (See Top...
# 2     ,#3 in Audible Audiobooks & Originals (See Top...
# 3     ,#5 in Audible Audiobooks & Originals (See Top...
# 4     ,#6 in Audible Audiobooks & Originals (See Top...
# ...                                                 ...
# 4347                                                 -1
# 4348                                                 -1
# 4349                                                 -1
# 4350                                                 -1
# 4351                                                 -1
#
#                                       Matched_Book_Name  \
# 0     Think Like a Monk: The Secret of How to Harnes...
# 1     Ikigai: The Japanese Secret to a Long and Happ...
# 2     The Subtle Art of Not Giving a F*ck: A Counter...
# 3     Atomic Habits: An Easy and Proven Way to Build...
# 4     Life's Amazing Secrets: How to Find Balance an...
# ...                                                 ...
# 4347  Le petit prince: Édition anniversaire [The Lit...
# 4348      Things I Wish I'd Known Before We Got Married
# 4349      Things I Wish I'd Known Before We Got Married
# 4350  The Disease Delusion: Conquering the Causes of...
# 4351  The Disease Delusion: Conquering the Causes of...
#
#                                             Book_Name_y  \
# 0     Think Like a Monk: The Secret of How to Harnes...
# 1     Ikigai: The Japanese Secret to a Long and Happ...
# 2     The Subtle Art of Not Giving a F*ck: A Counter...
# 3     Atomic Habits: An Easy and Proven Way to Build...
# 4     Life's Amazing Secrets: How to Find Balance an...
# ...                                                 ...
# 4347  Le petit prince: Édition anniversaire [The Lit...
# 4348      Things I Wish I'd Known Before We Got Married
# 4349      Things I Wish I'd Known Before We Got Married
# 4350  The Disease Delusion: Conquering the Causes of...
# 4351  The Disease Delusion: Conquering the Causes of...
#
#                       Author_y  Rating_y  Number of Reviews_y  Price_y  \
# 0                   Jay Shetty       4.9                313.0  10080.0
# 1                Héctor García       4.6               3658.0    615.0
# 2                  Mark Manson       4.4              20174.0  10378.0
# 3                  James Clear       4.6               4614.0    888.0
# 4               Gaur Gopal Das       4.6               4302.0   1005.0
# ...                        ...       ...                  ...      ...
# 4347  Antoine de Saint-Exupéry       4.5                 20.0    519.0
# 4348              Gary Chapman       4.7               1379.0    516.0
# 4349              Gary Chapman       4.7               1379.0    516.0
# 4350      Dr. Jeffrey S. Bland       4.7                256.0  12356.0
# 4351      Dr. Jeffrey S. Bland       4.7                256.0  12356.0
#
#       cluster
# 0           2
# 1           2
# 2           2
# 3           1
# 4           2
# ...       ...
# 4347        2
# 4348        2
# 4349        2
# 4350        2
# 4351        2
#
# [4352 rows x 15 columns]
