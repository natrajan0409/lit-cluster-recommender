# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import pandas as pd
from sklearn.cluster import KMeans
df=pd.read_csv('cleandata/merged_auduobook.csv')
df.head()

print(df.shape)
print(df.columns)

df['Book_Name_x'] =df['Book_Name_x'].str.lower()
vectorizer = TfidfVectorizer(stop_words='english')
x=vectorizer.fit_transform(df['Book_Name_x'])
# Out:
# (4352, 14)
# Index(['Book_Name_x', 'Author_x', 'Rating_x', 'Number of Reviews_x', 'Price_x',
#        'Description', 'Listening Time', 'Ranks and Genre', 'Matched_Book_Name',
#        'Book_Name_y', 'Author_y', 'Rating_y', 'Number of Reviews_y',
#        'Price_y'],
#       dtype='object')

# %%
cosine_sim = linear_kernel(X, X)
print(cosine_sim.shape)
# Out:
# (4352, 4352)

# %%
# KMeans Clustering
kmeans = KMeans(n_clusters=5, random_state=42)
cluster_labels = kmeans.fit_predict(x)
df['cluster'] = cluster_labels

# %%
print("Cluster Labels:", cluster_labels)
print("DataFrame with Clusters:\n", df)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print(recommend("Some Book Title", df, cosine_sim, top_n=5))
#       3 print("Cluster Labels:", cluster_labels)
#       4 print("DataFrame with Clusters:\n", df)
#
# Cell In[17], line 2, in recommend(book_title, df, cosine_sim, top_n)
#       1 def recommend(book_title,df,cosine_sim,top_n=5):
# ----> 2     idx=df[df['Book_Name_x']==book_title].index[0];
#       3     sim_score=list(enumerate(bookname[idx]))
#       4     sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
#
# File d:\workspace\lit-cluster-recommender\env\Lib\site-packages\pandas\core\indexes\base.py:5401, in Index.__getitem__(self, key)
#    5398 if is_integer(key) or is_float(key):
#    5399     # GH#44051 exclude bool, which would return a 2d ndarray
#    5400     key = com.cast_scalar_indexer(key)
# -> 5401     return getitem(key)
#    5403 if isinstance(key, slice):
#    5404     # This case is separated from the conditional above to avoid
#    5405     # pessimization com.is_bool_indexer and ndim checks.
#    5406     return self._getitem_slice(key)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import DBSCAN

# Load cleaned CSV
df = pd.read_csv(r"D:\workspace\lit-cluster-recommender\cleandata\merged_auduobook.csv")


# Use the correct column name from your file
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(df['Book_Name_x'])   # or df['description'] if that's the text field

# Apply DBSCAN with cosine similarity
dbscan = DBSCAN(eps=0.5, min_samples=5, metric='cosine')
cluster_labels = dbscan.fit_predict(X)

# Add cluster labels to DataFrame
df['cluster'] = cluster_labels

# Print results
print("Cluster Labels:", cluster_labels)
print(df[['Book_Name_x','cluster']].head())   # match the actual column name
# Out:
# Cluster Labels: [-1 -1 -1 ... -1 -1 -1]
#                                          Book_Name_x  cluster
# 0  Think Like a Monk: The Secret of How to Harnes...       -1
# 1  Ikigai: The Japanese Secret to a Long and Happ...       -1
# 2  The Subtle Art of Not Giving a F*ck: A Counter...       -1
# 3  Atomic Habits: An Easy and Proven Way to Build...       -1
# 4  Life's Amazing Secrets: How to Find Balance an...       -1
